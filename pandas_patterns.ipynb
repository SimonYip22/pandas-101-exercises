# %% [markdown]
# """
# pd.DataFrame(2D_list)
# pd.DataFrame({'column1': list1, 'column2': list2})
#
# pd.Series()
#
# df.shape()
# df.head()
# df.loc[row, column]
# df['new_column'] = expression
#
# df[column] # series
# df[[column]] # dataframe
#
# ser.unique()
# df.drop_duplicates(subset=columns, keep='first'/'last'/False, inplace=Boolean)
#
# df.dropna(axis=0 or 'index'/ 1 or 'columns', how='any'/'all', thresh=None, subset=None, inplace=False)
# pd.isna(df)
#
# df.fillna(value, inplace=True)
#
# df.rename(columns={old_name:new_name})
#
# df[column].astype(data type)
# df.astype({column : data type})
#
# df[column].fillna(value, inplace=True)
#
# pd.concat([df, df2], axis=0/1)
#
# df.columns = [new_column_names]
#
# df.pivot(index=row, columns=column, values=values)
#
# df.melt(id_vars=index, value_vars=rows, var_name=column, value_name=column values)
# df.sort_values(by=column_name, ascending=Boolean)
#
# pd.cut(df[column], bins=[], labels=labels, right=Boolean, include_lowest=Boolean)
# pd.qcut(df[column], q=number_of_quantiles, labels=labels, precision=precision, duplicates='drop')
#
# pd.merge(df1, df2, how='inner'/'outer'/'left'/'right', on=column_name, left_on=column_name, right_on=column_name)
#
# df.aggregate(functions, axis=0/1)
# df.aggregate({'column1': function1, 'column2': function2})
#
# df = pd.read_csv("filename.csv")
#
# df.hist()
#
# df = ser.to_frame().reset_index()
#
# ser1[~ser1.isin(ser2)]
#
# ser.quantile([0, 0.25, 0.5, 0.75, 1])
#
# ser.value_counts()
# ser.value_counts().index[]
#
# np.random.random(size=n)
# np.random.randint(high, size=n)
# np.random.randint(start, end, size=n)
#
# np.take(array_or_list, positions)
#
# df['column'].where(condition, otherwise)
#
# df = pd.DataFrame(ser.values.reshape(rows, columns))
# df = pd.DataFrame(ser.to_numpy().reshape(rows, columns))
#
# ser[condition].index
# np.argwhere(condition)
#
# ser.take(positions)
#
# # Mean squared error
# mse = ((truth - pred) ** 2).mean()
#
# ser.diff()
#
# pd.to_datetime()
# ser.dt.day                 # day of month
# ser.dt.month               # month number
# ser.dt.year                # year
# ser.dt.dayofyear           # day number in year
# ser.dt.day_name()          # weekday name
# ser.dt.isocalendar().week  # ISO week number
#
# df.groupby("category_column")["numeric_column"].mean()
#
# df[mask | mask]
# df[mask & mask]
#
# &   # element-wise AND
# |   # element-wise OR
# ~   # element-wise NOT
#
# df[column].str.startswith("string")
#
# pd.crosstab(rows=df['column1'], columns=df['column2'])
# df.groupby(['column1', 'column2']).size().unstack()

# %% [markdown]
# ## Visualization
#
# import matplotlib.pyplot as plt
#
# plt.bar(x_positions, heights)
#
# plt.hist(x, bins=5)
# plt.scatter(x, y)
# plt.pie(values, labels=labels)  # part-to-whole comparison
# plt.plot(x, y)
#
# plt.xlabel('x label')
# plt.ylabel('y label')
#
#
# plt.tight_layout()
#
# plt.show()
